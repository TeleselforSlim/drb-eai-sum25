# %% [markdown]
# # Sample works on `Week-01` activities
# - By Dr. B
# - Last modified: 2025-06-12 14:17:11
# - *Please use the provided `requirements.txt` to create the necessary virtual env with Python 3.10.15*

# %%
#!pip install pandas
#!pip install numpy
#!pip install matplotlib
#!pip install scipy
#!pip install scikit-learn
#!pip install openpyxl
#!pip install ucimlrepo
#!pip install aif360
# Out:
# ...
#   Using cached aif360-0.6.1-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached aif360-0.6.1-py3-none-any.whl (259 kB)
# ...

# %%
#Dr. B> I love loggings more than printings :D
import logging
#logging config
logging.basicConfig(
					level=logging.DEBUG,
					format='%(levelname)-6s | %(asctime)s | %(message)s'
					)
logger = logging.getLogger()

# %% [markdown]
# ## Part A: Activities involving Exploratory Data Analysis (EDA)
# 1. How many rows are in dataset: `week-01/datasets/A.csv`? How about in `week-01/datasets/B.txt` and in `week-01/datasets/C.csv`?

# %%
with open('datasets/A.csv','r') as f:
    counter = 0
    for line in f:
        counter += 1
    logger.info(f'num lines in A.csv is {counter}')
# Out:
# INFO   | 2025-06-12 16:12:30,170 | num lines in A.csv is 9001

# %%
#a better ~ time-efficient way
with open('datasets/A.csv','r') as f:
    logger.info(f'num lines in A.csv is {sum([1 for _ in f])}')
# Out:
# INFO   | 2025-06-12 16:12:30,190 | num lines in A.csv is 9001

# %%
with open('datasets/B.txt','r') as f:
    counter = 0
    for line in f:
        counter += 1
    logger.info(f'num lines in B.txt is {counter}')
# Out:
# INFO   | 2025-06-12 16:12:30,330 | num lines in B.txt is 232043

# %%
with open('datasets/C.csv','r') as f:
    counter = 0
    for line in f:
        counter += 1
    logger.info(f'num lines in C.csv is {counter}')
# Out:
# INFO   | 2025-06-12 16:12:30,346 | num lines in C.csv is 79

# %% [markdown]
# 2. Repeat the previous task to find out how many `samples` (i.e., instances) are there in each of the dataset?

# %%
import pandas as pd
A = pd.read_csv('datasets/A.csv',
                     sep=',', #default is comma (,)
                     header=0, #default is `infer` ~ header=0th row
                    )

# %%
logger.info(f'num of samples in A.csv is {A.shape[0]}')
# Out:
# INFO   | 2025-06-12 16:12:31,485 | num of samples in A.csv is 9000

# %%
B = pd.read_csv('datasets/B.txt',
                header=None, #no header row present
                sep='\s+',
               )

# %%
logger.info(f'num of samples in B.txt is {B.shape[0]}')
# Out:
# INFO   | 2025-06-12 16:12:32,392 | num of samples in B.txt is 232043

# %%
C = pd.read_csv('datasets/C.csv',
                header=0, #first row is header row
                sep=';',
                skiprows=[1] #skip the second row
               )

# %%
logger.info(f'num of samples in C.csv is {C.shape[0]}')
# Out:
# INFO   | 2025-06-12 16:12:32,444 | num of samples in C.csv is 77

# %% [markdown]
# 3. How many columns are there in each of the 3 datasets?

# %%
logger.info(f'num of columns in A.csv is {len(A.columns)}')
logger.info(f'num of columns in B.txt is {len(B.columns)}')
logger.info(f'num of columns in C.csv is {len(C.columns)}')
# Out:
# INFO   | 2025-06-12 16:12:32,465 | num of columns in A.csv is 13
# INFO   | 2025-06-12 16:12:32,472 | num of columns in B.txt is 14
# INFO   | 2025-06-12 16:12:32,476 | num of columns in C.csv is 16

# %% [markdown]
# 4. Compute the mean of the last (i.e., rightmost) column of `week-01/datasets/C.csv`?

# %%
logger.info(f'mean of rightmost column of C is {C[["rating"]].mean().iloc[0,]:.2f}')
# Out:
# INFO   | 2025-06-12 16:12:32,545 | mean of rightmost column of C is 42.67

# %% [markdown]
# 5. Where (i.e, in which sample) the two datasets: `week-01/datasets/B.txt` and `week-01/datasets/D.txt` differ?

# %%
#instead of writing a python script, let's use a shell command `diff`
# !diff datasets/B.txt datasets/D.txt
# Out:
# 112590c112590
# < USC00286460 1981   279   1511    261    916   1559    910   1351    386    855   1114    396   1192
# ---
# > USC00286460 1981   279   1511    261    916   1559    91l   1351    386    855   1114    396   1192

# %% [markdown]
# 6. What is the average credit score among the samples found in `week-01/datasets/A.csv`?

# %%
logger.info(f'Average credit score of {A[["CreditScore"]].mean().iloc[0,]:.2f}')
# Out:
# INFO   | 2025-06-12 16:12:33,890 | Average credit score of 650.12

# %% [markdown]
# 7. How many different countries are listed in `week-01/datasts/A.csv`?

# %%
logger.info(f"List of different countries: {A['Geography'].unique()}")
# Out:
# INFO   | 2025-06-12 16:12:33,948 | List of different countries: ['Spain' 'France' 'Germany']

# %%
logger.info(f'num of different countries in A is: {A["Geography"].nunique()}')
# Out:
# INFO   | 2025-06-12 16:12:33,987 | num of different countries in A is: 3

# %% [markdown]
# 8. Please briefly describe each of the 3 datasets (i.e., what the datasets are about)

# %% [markdown]
# * **A dataset**
# * Bank Customer Churn Prediction data.
# * Source: [Kaggle](https://www.kaggle.com/datasets/gauravtopre/bank-customer-churn-dataset)
#
#
# * **B dataset**
# * Monthly precipation values (normals) data from ~9000 weather stations from National Centers for Environmental Information between 1981-2010.
# * source [mly-prcp-filled.txt](https://www.ncei.noaa.gov/pub/data/normals/1981-2010/source-datasets/mly-prcp-filled.txt)
#
# *  **C dataset**
# *  dataset about 80 cereals and their nutrition facts
# *  Source [80-cereals](https://www.kaggle.com/datasets/crawford/80-cereals)

# %% [markdown]
# 9. Care to explore more of the datasets?

# %% [markdown]
# - **Please do it yourself**

# %% [markdown]
# ## Part B: Activities with an online dataset
# 1. Get the dataset: i) Go to [https://www.fueleconomy.gov](https://www.fueleconomy.gov), ii) Scroll down the page to find link to “Download EPA’s MPG Ratings” and click on it. iii) Locate the section titled Datasets for All Model Years (1984–2025)., iv) Click on Zipped CSV File to download the dataset. How many samples are there in the dataset? Also, how many features are there per sample

# %% [markdown]
# * I Downloaded the `vehicles.csv.zip` into the `datasets` directory.
# * And then, I unzipped it with `7z x vehicles.csv.zip`.
# * Now I have `vehicles.csv` file there.

# %%
vehicles_df = pd.read_csv('datasets/vehicles.csv',
                header=0,
                sep=',')
# Out:
# /var/folders/12/sb6k1cdx1dn2gkn_2l4ty8dr0000gn/T/ipykernel_35226/2605955451.py:1: DtypeWarning: Columns (74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   vehicles_df = pd.read_csv('datasets/vehicles.csv',

# %%
logger.info(f'Num of samples in vehicles.csv is {vehicles_df.shape[0]}')
logger.info(f'Num of features per sample in the vehicles.csv is {vehicles_df.shape[1]}')
# Out:
# INFO   | 2025-06-12 16:12:35,030 | Num of samples in vehicles.csv is 48617
# INFO   | 2025-06-12 16:12:35,036 | Num of features per sample in the vehicles.csv is 84

# %% [markdown]
# 2. Let’s filter the dataset. We are interested only with vehicle’s engine displacement (`displ`), model year (`year`), unadjusted mpg on highway (`UHighway`), unadjusted mpg on city (`UCity`) and the fuel type (`fuelType`). Create a dataframe that contains the filtered dataset.

# %%
data_filtered = vehicles_df[ ['displ', 'year','UHighway','UCity','fuelType'] ]

# %%
#Let's view first few samples
data_filtered.head(n=8)
# Out:
#    displ  year  UHighway    UCity fuelType
# 0    2.0  1985   35.0000  23.3333  Regular
# 1    4.9  1985   19.0000  11.0000  Regular
# 2    2.2  1985   47.0000  29.0000  Regular
# 3    5.2  1985   16.6667  12.2222  Regular
# 4    2.2  1993   32.0000  21.0000  Premium
# 5    1.8  1993   33.0000  27.0000  Regular
# 6    1.8  1993   41.0000  28.0000  Regular
# 7    1.6  1993   37.0000  29.0000  Regular

# %% [markdown]
# 3. Do the following:
#     * Plot a histogram of engine displacement data.
#     * Plot histograms for each of the attributes present in the filtered dataset.
#     * Plot a scatter plot between unadjusted highway mpg (UHighway) and engine displacement (displ).
#     * Plot a scatter plot between unadjusted city mpg (UCity) and engine displacement (displ).
#     * Plot a scatter-matrix between variables present in the filtered dataset.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3))
plt.hist(data_filtered['displ'],bins=60)
# Out:
# DEBUG  | 2025-06-12 16:12:35,539 | matplotlib data path: /Users/ashis/GITs/drb-eai-sum25/.venv/lib/python3.10/site-packages/matplotlib/mpl-data
# DEBUG  | 2025-06-12 16:12:35,550 | CONFIGDIR=/Users/ashis/.matplotlib
# DEBUG  | 2025-06-12 16:12:35,572 | interactive is False
# DEBUG  | 2025-06-12 16:12:35,573 | platform is darwin
# DEBUG  | 2025-06-12 16:12:35,729 | CACHEDIR=/Users/ashis/.matplotlib
# DEBUG  | 2025-06-12 16:12:35,738 | Using fontManager instance from /Users/ashis/.matplotlib/fontlist-v390.json
# DEBUG  | 2025-06-12 16:12:36,146 | Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG  | 2025-06-12 16:12:36,148 | Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG  | 2025-06-12 16:12:36,154 | findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# ...

# %%
data_filtered['fuelType'].unique()
# Out:
# array(['Regular', 'Premium', 'Diesel', 'CNG', 'Gasoline or natural gas',
#        'Gasoline or E85', 'Electricity', 'Gasoline or propane',
#        'Premium or E85', 'Midgrade', 'Premium Gas or Electricity',
#        'Regular Gas and Electricity', 'Premium and Electricity',
#        'Regular Gas or Electricity', 'Hydrogen'], dtype=object)

# %%
data_filtered.hist(bins=100,figsize=(10,7))
# Out:
# array([[<Axes: title={'center': 'displ'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'UHighway'}>,
#         <Axes: title={'center': 'UCity'}>]], dtype=object)
# DEBUG  | 2025-06-12 16:12:37,799 | findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# DEBUG  | 2025-06-12 16:12:37,800 | findfont: score(FontEntry(fname='/Users/ashis/GITs/drb-eai-sum25/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG  | 2025-06-12 16:12:37,801 | findfont: score(FontEntry(fname='/Users/ashis/GITs/drb-eai-sum25/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# ...

# %%
#scatter of UHighway vs displ
data_filtered.plot(kind='scatter', 
                   xlim=[0,10],
                   x='displ',
                   y='UHighway',
                   s=2, #size of each point
                   c='g', #color
                   marker='s', #square-box-filled
                  )
# Out:
# <Axes: xlabel='displ', ylabel='UHighway'>

# %%
#scatter of UHighway vs displ
data_filtered.plot(kind='scatter', 
                   xlim=[0,10],
                   x='displ',
                   y='UCity',
                   s=2, #size of each point
                   c='r', #color
                   marker='s', #square-box-filled
                  )
# Out:
# <Axes: xlabel='displ', ylabel='UCity'>

# %%
#scatter-matrix
pd.plotting.scatter_matrix(data_filtered,
               figsize=(12,8),
               alpha=0.2,
               diagonal='kde'
              )
# Out:
# array([[<Axes: xlabel='displ', ylabel='displ'>,
#         <Axes: xlabel='year', ylabel='displ'>,
#         <Axes: xlabel='UHighway', ylabel='displ'>,
#         <Axes: xlabel='UCity', ylabel='displ'>],
#        [<Axes: xlabel='displ', ylabel='year'>,
#         <Axes: xlabel='year', ylabel='year'>,
#         <Axes: xlabel='UHighway', ylabel='year'>,
#         <Axes: xlabel='UCity', ylabel='year'>],
#        [<Axes: xlabel='displ', ylabel='UHighway'>,
#         <Axes: xlabel='year', ylabel='UHighway'>,
#         <Axes: xlabel='UHighway', ylabel='UHighway'>,
#         <Axes: xlabel='UCity', ylabel='UHighway'>],
#        [<Axes: xlabel='displ', ylabel='UCity'>,
#         <Axes: xlabel='year', ylabel='UCity'>,
#         <Axes: xlabel='UHighway', ylabel='UCity'>,
#         <Axes: xlabel='UCity', ylabel='UCity'>]], dtype=object)
# DEBUG  | 2025-06-12 16:12:46,071 | findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=8.0.
# ...

# %% [markdown]
# 4. Find outlier samples that do not have value for engine displacement. Please report how many such samples did you find?
# We now have several option to amend our dataset for further processing. Option 1: Remove the samples, or, Option 2: fill the value with any of the central tendency.
# For this question, please choose option 2 and prepare the dataset.

# %%
logger.info(f'num of missing values in displ field is {sum(data_filtered.displ.isnull())}')
# Out:
# INFO   | 2025-06-12 16:12:56,902 | num of missing values in displ field is 1091

# %%
data_filtered_preprocessed = data_filtered.fillna(value=data_filtered.displ.mean())

# %%
logger.info(f'num of missing values in displ field is {sum(data_filtered_preprocessed.displ.isnull())}')
# Out:
# INFO   | 2025-06-12 16:12:56,959 | num of missing values in displ field is 0

# %% [markdown]
# 6. Shuffle the dataset

# %%
data_shuffled = data_filtered_preprocessed.sample(frac=1 #return all rows
                                                 )

# %% [markdown]
# 7. Take one half of the dataset as training set, and the remaining half as test set. Please separate independent (displ) and dependent variable (UHighway)

# %%
n_training = data_shuffled.shape[0]//2
logger.info(f'Number of samples in the whole dataset is {data_shuffled.shape[0]}')
logger.info(f'Number of samples in the training split is {n_training}')
# Out:
# INFO   | 2025-06-12 16:12:57,007 | Number of samples in the whole dataset is 48617
# INFO   | 2025-06-12 16:12:57,009 | Number of samples in the training split is 24308

# %%
#Now, here is the training and test data_frames
data_train = data_shuffled.iloc[0:n_training,:]
data_test = data_shuffled.iloc[n_training:,:]

# %%
#separate indepedent (x) and dependent (y) variables
data_train_x = data_train['displ'].values.reshape(-1,1)
data_train_y = data_train['UHighway'].values.reshape(-1,1)

data_test_x = data_test['displ'].values.reshape(-1,1)
data_test_y = data_test['UHighway'].values.reshape(-1,1)

# %% [markdown]
# 8. Build a linear regression model based on the training dataset.

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=data_train_x,
          y=data_train_y)
# Out:
# LinearRegression()

# %% [markdown]
# 9. Use the trained model to predict Uhighway of the test dataset

# %%
pred = model.predict(data_test_x)

# %% [markdown]
# 10. Evaluate the model performance (in terms of Root Mean Squared Error, and R-squared score)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

logger.info(f'RMSE = {np.sqrt(mean_squared_error(data_test_y, pred))}')
logger.info(f'R-squared error = {r2_score(data_test_y, pred)}')
# Out:
# INFO   | 2025-06-12 16:12:58,085 | RMSE = 15.281659036286312
# INFO   | 2025-06-12 16:12:58,091 | R-squared error = 0.1445361882961974

# %% [markdown]
# 11. pick one sample from the test set, and estimate MPG. How bad was it?

# %%
import random

sample_index = random.randint(0,data_test_x.shape[0])
a_test_sample_x = data_test_x[sample_index].reshape(-1,1)
a_test_sample_y = data_test_y[sample_index].reshape(-1,1)

logger.info(f'Test sample: displ = {a_test_sample_x[0,0]:.4f}, MPG={a_test_sample_y[0,0]:.4f}')
logger.info(f'Predicted MPG = {model.predict(a_test_sample_x)[0,0]:.4f}')
# Out:
# INFO   | 2025-06-12 16:12:58,114 | Test sample: displ = 5.7000, MPG=22.7508
# INFO   | 2025-06-12 16:12:58,118 | Predicted MPG = 24.8919

# %% [markdown]
# ## Part C: Activities with a classification problem

# %% [markdown]
# 1. A classification task for you: Get the dataset first: go to [this link at https://www.muratkoklu.com/datasets/](https://www.muratkoklu.com/datasets/), and download the `Date Fruit Datasets`. You will get the `Date Fruit Datasets.zip`. Unzip it to get the `Date Fruit Datasets.xlsx` file among other files. We will be working on the `xlsx` file today. Please note: the dataset is in the `Date_Fruit_Datasets` sheet in the `xlsx`file.

# %% [markdown]
# * I downloaded the `Date_Fruit_Datasets.zip` into the `datasets/` directory and unzip with `7z x Date_Fruit_Datasets.zip`, and now I got the `Date_Fruit_Datasets/Date_Fruit_Datasets.xlsx` file.

# %% [markdown]
# 2. Load the dataset and tell i) How many samples are there in the dataset? ii) how many features are there per sample, excluding the class/type label? iii) Print the number of unique classes (i.e., fruit types), list the class names, and their frequency distribution.

# %% [markdown]
# * In case of the following error while calling `pd.read_excel()` function:
# ```
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
# ```
#     * Do as it says: `pip install openpyxl`

# %%
import pandas as pd
df = pd.read_excel('datasets/Date_Fruit_Datasets/Date_Fruit_Datasets.xlsx', sheet_name='Date_Fruit_Datasets')

# %%
logger.info(f'Num of samples =  {df.shape[0]}')
logger.info(f'Num of features per sample = {df.shape[1]-1}')
logger.info(f'Num of unique classes = {df["Class"].nunique()}')
logger.info(f'list of unique classes = {df["Class"].unique()}')
logger.info(f'Frequency distribution of the classes:\n{df["Class"].value_counts()}')
# Out:
# INFO   | 2025-06-12 16:12:59,023 | Num of samples =  898
# INFO   | 2025-06-12 16:12:59,026 | Num of features per sample = 34
# INFO   | 2025-06-12 16:12:59,028 | Num of unique classes = 7
# INFO   | 2025-06-12 16:12:59,030 | list of unique classes = ['BERHI' 'DEGLET' 'DOKOL' 'IRAQI' 'ROTANA' 'SAFAVI' 'SOGAY']
# INFO   | 2025-06-12 16:12:59,036 | Frequency distribution of the classes:
# Class
# DOKOL     204
# SAFAVI    199
# ROTANA    166
# DEGLET     98
# SOGAY      94
# IRAQI      72
# BERHI      65
# Name: count, dtype: int64

# %% [markdown]
# 3. List mean, stdev, min, max of each of the features in the dataset

# %%
df.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# count     898.000000   898.000000   898.000000  898.000000    898.000000
# mean   298295.207127  2057.660953   750.811994  495.872785      0.737468
# std    107245.205337   410.012459   144.059326  114.268917      0.088727
# min      1987.000000   911.828000   336.722700    2.283200      0.344800
# 25%    206948.000000  1726.091500   641.068650  404.684375      0.685625
# 50%    319833.000000  2196.345450   791.363400  495.054850      0.754700
# 75%    382573.000000  2389.716575   858.633750  589.031700      0.802150
# max    546063.000000  2811.997100  1222.723000  766.453600      1.000000
#
#           EQDIASQ    SOLIDITY    CONVEX_AREA      EXTENT  ASPECT_RATIO  ...  \
# count  898.000000  898.000000     898.000000  898.000000    898.000000  ...
# mean   604.577938    0.981840  303845.592428    0.736267      2.131102  ...
# std    119.593888    0.018157  108815.656947    0.053745     17.820778  ...
# ...

# %% [markdown]
# 4. Shuffle the data samples.

# %%
data_shuffled = df.sample(frac=1) #return all rows)

# %% [markdown]
# 5. Split the dataset into training (80%) and test (20%)

# %%
#Split independent (x) and dependent variables (y)
X = data_shuffled.iloc[:,:-1]
y = data_shuffled.iloc[:,-1]

# %%
#Now, train and test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# 6. Scale all independent features.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #please save this scaler object for later use

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# 7. Build a classifier with the training set.

# %%
#kNN classifier
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors=3)
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#Decision tree classifier
from sklearn.tree import DecisionTreeClassifier

model_tree = DecisionTreeClassifier(max_depth=5)
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
#RandomForest classifier
from sklearn.ensemble import RandomForestClassifier

model_forest = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
model_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
#Naive Bayes classifier
from sklearn.naive_bayes import GaussianNB
model_nb = GaussianNB()
model_nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# 8. Predict class label of just one sample picked from the test set.

# %%
import random

sample_index = random.randint(0,X_test_scaled.shape[0])
a_test_sample_x = X_test.iloc[sample_index,:]
a_test_sample_y = y_test.iloc[sample_index]

logger.info(f'Test sample: {a_test_sample_x}, \nClass={a_test_sample_y}')
a_test_sample_x = np.array(a_test_sample_x).reshape(1,-1)
logger.info(f'Predicted Class = {model_knn.predict(a_test_sample_x)}')
# Out:
# INFO   | 2025-06-12 16:23:50,515 | Test sample: AREA             1.533530e+05
# PERIMETER        1.501488e+03
# MAJOR_AXIS       5.859454e+02
# MINOR_AXIS       3.352349e+02
# ECCENTRICITY     8.202000e-01
# EQDIASQ          4.418768e+02
# SOLIDITY         9.885000e-01
# CONVEX_AREA      1.551380e+05
# EXTENT           8.264000e-01
# ASPECT_RATIO     1.747900e+00
# ROUNDNESS        8.548000e-01
# COMPACTNESS      7.541000e-01
# SHAPEFACTOR_1    3.800000e-03
# SHAPEFACTOR_2    2.200000e-03
# SHAPEFACTOR_3    5.687000e-01
# SHAPEFACTOR_4    9.940000e-01
# MeanRR           1.261267e+02
# MeanRG           1.140718e+02
# MeanRB           1.079288e+02
# StdDevRR         3.244030e+01
# StdDevRG         2.775920e+01
# StdDevRB         2.620870e+01
# SkewRR          -7.002000e-01
# SkewRG          -1.769000e-01
# SkewRB          -1.947000e-01
# KurtosisRR       3.010100e+00
# KurtosisRG       2.612100e+00
# KurtosisRB       2.898000e+00
# EntropyRR       -2.562070e+10
# ...

# %% [markdown]
# 9. Evaluate the model performance based on the test set in terms of accuracy, precision, recall and F1.

# %%
y_pred = model_knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, \
	classification_report,\
	accuracy_score,precision_score, recall_score, f1_score

cm = confusion_matrix(y_test, y_pred)
logger.info(f"Confusion Matrix:\n{cm}", )

logger.info(f"Classification report:\n {classification_report(y_test,y_pred)}")

accuracy = accuracy_score(y_test, y_pred)
logger.info(f"Accuracy: {accuracy:.4f}")

precision = precision_score(y_test, y_pred, average='weighted')
logger.info(f"Precision: {precision:.4f}")

recall = recall_score(y_test, y_pred, average='weighted')
logger.info(f"Recall: {recall:.4f}")

f1 = f1_score(y_test, y_pred, average='weighted')
logger.info(f"F1-Score: {f1:.4f}")
# Out:
# INFO   | 2025-06-12 16:28:40,931 | Confusion Matrix:
# [[ 2  3  2  1  3  0  2]
#  [ 4  5  6  1  1  1  2]
#  [ 1  2 31  0  0  0  1]
#  [ 2  1  3  8  3  0  0]
#  [ 0  2  0  0 36  0  0]
#  [ 0  0  2  0  0 38  0]
#  [ 4  3  4  0  0  0  6]]
# INFO   | 2025-06-12 16:28:40,993 | Classification report:
#                precision    recall  f1-score   support
#
#        BERHI       0.15      0.15      0.15        13
#       DEGLET       0.31      0.25      0.28        20
#        DOKOL       0.65      0.89      0.75        35
#        IRAQI       0.80      0.47      0.59        17
#       ROTANA       0.84      0.95      0.89        38
#       SAFAVI       0.97      0.95      0.96        40
#        SOGAY       0.55      0.35      0.43        17
#
#     accuracy                           0.70       180
#    macro avg       0.61      0.57      0.58       180
# weighted avg       0.69      0.70      0.69       180
#
# INFO   | 2025-06-12 16:28:40,996 | Accuracy: 0.7000
# ...

# %% [markdown]
# ## Part D: Machine Learning Pipeline
# 1. Please establish a `scikit-learn` `Pipeline` for any of the above 2 activities.
# 	- Reference 1: [https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html)
# 	- Reference 2: [Example code 1](https://scikit-learn.org/stable/auto_examples/compose/plot_column_transformer_mixed_types.html#sphx-glr-auto-examples-compose-plot-column-transformer-mixed-types-py)

# %% [markdown]
# ## Part E: A short orientation on bias detection and mitigation with `aif360` package
# 1. Here is the link to retrieve the German Credit dataset: [https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data](https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data)
#   * Easy way to import into Python workspace:
# ```
# !pip install ucimlrepo
# from ucimlrepo import fetch_ucirepo
#
# # fetch dataset
# statlog_german_credit_data = fetch_ucirepo(id=144)
#
# # data (as pandas dataframes)
# X = statlog_german_credit_data.data.features
# y = statlog_german_credit_data.data.targets
#
# # metadata
# print(statlog_german_credit_data.metadata)
#
# # variable information
# print(statlog_german_credit_data.variables)
# ```
# 2. Let's use the German credit dataset, splitting it into a training and test dataset.
# 3. We will look for bias in the creation of a machine learning model to predict if an applicant should be given credit based on various features from a typical credit application.  The protected attribute will be "Age", with "1" (older than or equal to 25) and "0" (younger than 25) being the values for the privileged and unprivileged groups, respectively.
# 4. Firstly, we will check for bias in the initial training data. Then, we apply a `Reweighing` based bias mitigation strategy from the `aif360` package and re-assess the bias. Here are the complete steps involved. But, here we will mainly focus on detecting biases.
# * **Step 1**: Write import statements
# * **Step 2**: Set bias detection options, load dataset, and split between train and test
# * **Step 3**: Compute fairness metric on original training dataset. Please refer to the documentation: `from aif360.metrics import BinaryLabelDatasetMetric`
# * **Step 4**: Mitigate bias by transforming the original dataset. Please refer to the documentation: `from aif360.algorithms.preprocessing import Reweighing`.
# * **Step 5**: Compute fairness metric on transformed training dataset

# %% [markdown]
# * The goal of this tutorial is to introduce the basics of exploratory data analysis while detecting bias in a critical problem.
# * A machine learning model makes predictions of an outcome for a particular instance.
#   * Given an instance of a loan application, predict if the applicant will repay the loan.
#   * The model makes these predictions based on a training dataset, where many other instances (other loan applications) and actual outcomes (whether they repaid) are provided.
#   * Thus, a machine learning algorithm will attempt to find patterns, or generalizations, in the training dataset to use when a prediction for a new instance is needed.
# * For example, one pattern it might discover is
#   > "if a person has salary > USD 40K and has outstanding debt < USD 5, they will repay the loan"
# * In many domains this technique, called supervised machine learning, has worked very well.
#
# * However, sometimes the patterns that are found may not be desirable or may even be illegal.
#   * For example, a loan repay model may determine that age plays a significant role in the prediction of repayment because the training dataset happened to have better repayment for one age group than for another.
#     * This raises two problems:
#       1.  the training dataset may not be representative of the true population of people of all age groups, and
#       2.  even if it is representative, it is illegal to base any decision on a applicant's age, regardless of whether this is a good prediction based on historical data.
#
# * After detection of such biases in the model, bias mitigators can be used to overcome bias in the workflow to produce a more fair outcome, which will be covered later in this course.
#
# * The loan scenario describes an intuitive example of illegal bias. However, not all undesirable bias in machine learning is illegal it may also exist in more subtle ways.
#   * For example, a loan company may want a diverse portfolio of customers across all income levels, and thus, will deem it undesirable if they are making more loans to high income levels over low income levels.
#     * Although this is not illegal or unethical, it is undesirable for the company's strategy.
#
# As these two examples illustrate, a bias detection and/or mitigation solutions are to be tailored to the particular bias of interest.  More specifically, it needs to know the attribute or attributes, called **protected attributes**, that are of interest: **race** is one example of a **protected attribute** and **age** is a second.

# %%
#uci repo related packages
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# * **Step 2 Load dataset, specifying protected attribute, and split dataset into train and test**
# - In Step 2 we load the initial dataset, setting the protected attribute to be age.  We then splits the original dataset into training and testing datasets.  Although we will use only  the training dataset in this tutorial, a normal workflow would also use a test dataset for assessing the efficacy (accuracy, fairness, etc.) during the development of a machine learning model.  Finally, we set two variables (to be used in Step 3) for the privileged (1) and unprivileged (0) values for the age attribute.  These are key inputs for detecting and mitigating bias, which will be Step 3 and Step 4.

# %%
dataset_orig = fetch_ucirepo(id=144)
# data (as pandas dataframes) 
X = dataset_orig.data.features 
y = dataset_orig.data.targets 

logger.info(f'\nX.shape = {X.shape}\ny.shape = {y.shape}')
# Out:
# INFO   | 2025-06-12 16:34:46,182 |
# X.shape = (1000, 20)
# y.shape = (1000, 1)

# %%
# metadata 
logger.info(dataset_orig.metadata)
# Out:
# INFO   | 2025-06-12 16:35:04,712 | {'uci_id': 144, 'name': 'Statlog (German Credit Data)', 'repository_url': 'https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data', 'data_url': 'https://archive.ics.uci.edu/static/public/144/data.csv', 'abstract': 'This dataset classifies people described by a set of attributes as good or bad credit risks. Comes in two formats (one all numeric). Also comes with a cost matrix', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1000, 'num_features': 20, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Other', 'Marital Status', 'Age', 'Occupation'], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1994, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5NC77', 'creators': ['Hans Hofmann'], 'intro_paper': None, 'additional_info': {'summary': 'Two datasets are provided.  the orig
# ...

# %%
# variable information 
logger.info(dataset_orig.variables)
# Out:
# INFO   | 2025-06-12 16:35:17,110 |            name     role         type     demographic  \
# 0    Attribute1  Feature  Categorical            None
# 1    Attribute2  Feature      Integer            None
# 2    Attribute3  Feature  Categorical            None
# 3    Attribute4  Feature  Categorical            None
# 4    Attribute5  Feature      Integer            None
# 5    Attribute6  Feature  Categorical            None
# 6    Attribute7  Feature  Categorical           Other
# 7    Attribute8  Feature      Integer            None
# 8    Attribute9  Feature  Categorical  Marital Status
# 9   Attribute10  Feature  Categorical            None
# 10  Attribute11  Feature      Integer            None
# 11  Attribute12  Feature  Categorical            None
# 12  Attribute13  Feature      Integer             Age
# 13  Attribute14  Feature  Categorical            None
# 14  Attribute15  Feature  Categorical           Other
# 15  Attribute16  Feature      Integer            None
# ...

# %%
protected_attribute_names=['age'] 	# this dataset also contains protected
                                    # attribute for "sex" which we do not
                                    # consider in this evaluation
privileged_classes=[lambda x: x >= 25] # age >=25 is considered privileged

features_to_drop=['personal_status', 'sex'] # ignore sex-related attributes

privileged_groups = [{'age': 1}]
unprivileged_groups = [{'age': 0}]

# %%
from aif360.datasets import GermanDataset
from aif360.metrics import BinaryLabelDatasetMetric
from aif360.algorithms.preprocessing import Reweighing

from IPython.display import Markdown, display
# Out:
# WARNING | 2025-06-12 16:36:35,077 | No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING | 2025-06-12 16:36:35,095 | No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING | 2025-06-12 16:36:35,103 | No module named 'fairlearn': ExponentiatedGradientReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING | 2025-06-12 16:36:35,106 | No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING | 2025-06-12 16:36:35,110 | No module named 'inFairness': SenSeI and SenSR will be unavailable. To install, run:
# pip install 'aif360[inFairness]'
# WARNING | 2025-06-12 16:36:35,116 | No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'

# %% [markdown]
# * If you get the following error message, please do as it says:
#
# >IOError: [Errno 2] No such file or directory: 'xxx/.venv/lib/python3.10/site-packages/aif360/datasets/../data/raw/german/german.data'
# To use this class, please download the following files:
#
# 	https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.data
# 	https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.doc
#
# >and place them, as-is, in the folder:
#
# 	xxx/.venv/lib/python3.10/site-packages/aif360/data/raw/german
#
# >An exception has occurred, use %tb to see the full traceback.
#
# `SystemExit: 1
# xxx/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)`

# %%
dataset_orig = GermanDataset(
    protected_attribute_names=['age'],           # this dataset also contains protected
                                                 # attribute for "sex" which we do not
                                                 # consider in this evaluation
    privileged_classes=[lambda x: x >= 25],      # age >=25 is considered privileged
    features_to_drop=['personal_status', 'sex'] # ignore sex-related attributes
)

dataset_orig_train, dataset_orig_test = dataset_orig.split([0.7], shuffle=True)

# %% [markdown]
# * **Step 3 Compute fairness metric on original training dataset**
# * Now that we've identified the protected attribute 'age' and defined privileged and unprivileged values, we can use aif360 to detect bias in the dataset.
# * One simple test is to compare the percentage of favorable results for the privileged and unprivileged groups, subtracting the former percentage from the latter.
# * A negative value indicates less favorable outcomes for the unprivileged groups.
# * This is implemented in the method called mean_difference on the BinaryLabelDatasetMetric class.
# * The code below performs this check and displays the output, showing that the difference is -0.136.

# %%
metric_orig_train = BinaryLabelDatasetMetric(dataset_orig_train, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)
logger.info(f'Measures of bias on the Original training dataset')
logger.info(f"Difference in mean outcomes between unprivileged and privileged groups = {metric_orig_train.mean_difference():.4f}")
logger.info(f'SPD = {metric_orig_train.statistical_parity_difference():.4f}')
logger.info(f'DI = {metric_orig_train.disparate_impact():.4f}')
# Out:
# INFO   | 2025-06-12 16:45:24,961 | Measures of bias on the Original training dataset
# INFO   | 2025-06-12 16:45:24,968 | Difference in mean outcomes between unprivileged and privileged groups = -0.1360
# INFO   | 2025-06-12 16:45:24,974 | SPD = -0.1360
# INFO   | 2025-06-12 16:45:24,976 | DI = 0.8167

# %% [markdown]
# * **Step 4 Mitigate bias by transforming the original dataset**
# * The previous step showed that the privileged group was getting 17% more positive outcomes in the training dataset.   Since this is not desirable, we are going to try to mitigate this bias in the training dataset.  As stated above, this is called _pre-processing_ mitigation because it happens before the creation of the model.
#
# * AI Fairness 360 implements several pre-processing mitigation algorithms.  We will choose the Reweighing algorithm [1], which is implemented in the `Reweighing` class in the `aif360.algorithms.preprocessing` package.  This algorithm will transform the dataset to have more equity in positive outcomes on the protected attribute for the privileged and unprivileged groups.
#
# * We then call the fit and transform methods to perform the transformation, producing a newly transformed training dataset (dataset_transf_train).
#
# `[1] F. Kamiran and T. Calders,  "Data Preprocessing Techniques for Classification without Discrimination," Knowledge and Information Systems, 2012.`

# %%
RW = Reweighing(unprivileged_groups=unprivileged_groups,
                privileged_groups=privileged_groups)
dataset_transf_train = RW.fit_transform(dataset_orig_train)

# %% [markdown]
# * **Step 5 Compute fairness metric on transformed dataset**
# * Now that we have a transformed dataset, we can check how effective it was in removing bias by using the same metric we used for the original training dataset in Step 3.  Once again, we use the function mean_difference in the BinaryLabelDatasetMetric class.   We see the mitigation step was very effective, the difference in mean outcomes is now 0.0.  So we went from a 17% advantage for the privileged group to equality in terms of mean outcome.

# %%
metric_transf_train = BinaryLabelDatasetMetric(dataset_transf_train, 
                                               unprivileged_groups=unprivileged_groups,
                                               privileged_groups=privileged_groups)
logger.info(f'Measures of bias on the transformed training dataset')
logger.info(f"Difference in mean outcomes between unprivileged and privileged groups = {metric_transf_train.mean_difference():.4f}")
logger.info(f'SPD = {metric_transf_train.statistical_parity_difference():.4f}')
logger.info(f'DI = {metric_transf_train.disparate_impact():.4f}')
# Out:
# INFO   | 2025-06-12 16:48:25,395 | Measures of bias on the transformed training dataset
# INFO   | 2025-06-12 16:48:25,403 | Difference in mean outcomes between unprivileged and privileged groups = 0.0000
# INFO   | 2025-06-12 16:48:25,405 | SPD = 0.0000
# INFO   | 2025-06-12 16:48:25,406 | DI = 1.0000

# %% [markdown]
# * **Summary**
# * The purpose of this tutorial is to give a new user to bias detection and mitigation a gentle introduction to some of the functionality of AI Fairness 360.
# * There are many metrics one can use to detect the presence of bias. AI Fairness 360 provides many of them for your use. Since it is not clear which of these metrics to use, we also provide some guidance. Likewise, there are many different bias mitigation algorithms one can employ, many of which are in AI Fairness 360. Other tutorials will demonstrate the use of some of these metrics and mitigations algorithms.
# * As mentioned earlier, both fairness metrics and mitigation algorithms can be performed at various stages of the machine learning pipeline.
# * I recommend checking for bias as often as possible, using as many metrics are relevant for the application domain.
# * We also recommend incorporating bias detection in an automated continuous integration pipeline to ensure bias awareness as a software project evolves.
